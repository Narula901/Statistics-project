# %%
import pyodbc

# %%
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=DESKTOP-J61LTVV;'
                      'Database=Jackson Dataset;'
                      'Trusted_Connection=yes;')

cursor = conn.cursor()
cursor.execute('select * from [dbo].[ASN Data]')

# %%
for i in cursor:
    print(i)
# Out:
# ('JAKSON_KAROLI', '2022-05-08 00:23:20', 'AASN/2223/371', '2022-05-08 00:23:34', 'OPS1001', 'OPENING STOCK', 'OPS070522-2', '1900-01-01 00:00:00', '2022-08-05 00:00:00', '146A101111151111', '146A101111151111', 'SHM 50/32N IN MOC 01 KBL PUMP', 1, 'PCS', 'Closed', 1, 'OPS070522-2', '2022-05-07 00:00:00', '1461420022', 0, '1461420022', None)
# ('JAKSON_KAROLI', '2022-05-08 00:23:20', 'AASN/2223/371', '2022-05-08 00:23:34', 'OPS1001', 'OPENING STOCK', 'OPS070522-2', '1900-01-01 00:00:00', '2022-08-05 00:00:00', '146A101111151111', '146A101111151111', 'SHM 50/32N IN MOC 01 KBL PUMP', 1, 'PCS', 'Closed', 1, 'OPS070522-2', '2022-05-07 00:00:00', '1461421002', 0, '1461421002', None)
# ...

# %%
import pandas as pd
df = pd.read_sql("select * from [dbo].[ASN Data]", conn)

# %%
df.head(5)
# Out:
#     LocationCode            CreatedOn             No      ReleaseDatetime  \
# 0  JAKSON_KAROLI  2022-05-08 00:23:20  AASN/2223/371  2022-05-08 00:23:34
# 1  JAKSON_KAROLI  2022-05-08 00:23:20  AASN/2223/371  2022-05-08 00:23:34
# 2  JAKSON_KAROLI  2022-05-08 00:23:20  AASN/2223/371  2022-05-08 00:23:34
# 3  JAKSON_KAROLI  2022-05-08 00:23:20  AASN/2223/371  2022-05-08 00:23:34
# 4  JAKSON_KAROLI  2022-05-08 00:23:20  AASN/2223/371  2022-05-08 00:23:34
#
#   VendorCode     VendorName         PONO               PODate  \
# 0    OPS1001  OPENING STOCK  OPS070522-2  1900-01-01 00:00:00
# 1    OPS1001  OPENING STOCK  OPS070522-2  1900-01-01 00:00:00
# 2    OPS1001  OPENING STOCK  OPS070522-2  1900-01-01 00:00:00
# 3    OPS1001  OPENING STOCK  OPS070522-2  1900-01-01 00:00:00
# 4    OPS1001  OPENING STOCK  OPS070522-2  1900-01-01 00:00:00
#
#     PlannedReceiptDate            ItemNo  ... Qty  UOM  Status CreatedBy  \
# ...

# %%
df.describe()
# Out:
#           Qty    CreatedBy     MRP
# count  4980.0  4980.000000  4980.0
# mean      1.0     5.894177     0.0
# std       0.0     6.949062     0.0
# min       1.0     1.000000     0.0
# 25%       1.0     1.000000     0.0
# 50%       1.0     1.000000     0.0
# 75%       1.0    16.000000     0.0
# max       1.0    16.000000     0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4980 entries, 0 to 4979
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   LocationCode        4980 non-null   object
#  1   CreatedOn           4980 non-null   object
#  2   No                  4980 non-null   object
#  3   ReleaseDatetime     4980 non-null   object
#  4   VendorCode          4980 non-null   object
#  5   VendorName          4980 non-null   object
#  6   PONO                4980 non-null   object
#  7   PODate              4980 non-null   object
#  8   PlannedReceiptDate  4980 non-null   object
#  9   ItemNo              4980 non-null   object
#  10  ItemNo2             4980 non-null   object
#  11  Description         4980 non-null   object
#  12  Qty                 4980 non-null   int64
#  13  UOM                 4980 non-null   object
#  14  Status              4980 non-null   object
# ...

# %%
df.unique(self)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19688/3910212497.py in <module>
# ----> 1 df.unique(self)
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
from numpy import unique
# load the dataset
#data = loadtxt('oil-spill.csv', delimiter=',')
# summarize the number of unique values in each column
for i in range(df.shape[1]):
    print(i, len(unique(df[:, i])))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10856/2961516573.py in <module>
#       4 # summarize the number of unique values in each column
#       5 for i in range(df.shape[1]):
# ----> 6     print(i, len(unique(df[:, i])))
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3359             casted_key = self._maybe_cast_indexer(key)
#    3360             try:
# ...

# %%
# summarize the number of unique values for each column using numpy
from numpy import loadtxt
from numpy import unique
# load the dataset
data = loadtxt('oil-spill.csv', delimiter=',')
# summarize the number of unique values in each column
for i in range(data.shape[1]):
    print(i, len(unique(data[:, i])))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10856/2831066805.py in <module>
#       3 from numpy import unique
#       4 # load the dataset
# ----> 5 data = loadtxt('oil-spill.csv', delimiter=',')
#       6 # summarize the number of unique values in each column
#       7 for i in range(data.shape[1]):
#
# c:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1063             fname = os_fspath(fname)
#    1064         if _is_string_like(fname):
# -> 1065             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1066             fencoding = getattr(fh, 'encoding', 'latin1')
#    1067             fh = iter(fh)
#
# ...

# %%
df.nunique()
# Out:
# LocationCode             1
# CreatedOn              108
# No                     375
# ReleaseDatetime        102
# VendorCode               9
# VendorName               9
# PONO                   120
# PODate                  45
# PlannedReceiptDate      25
# ItemNo                 694
# ItemNo2                694
# Description            703
# Qty                      1
# UOM                      1
# Status                   2
# CreatedBy                3
# InvoiceNo              375
# InvoiceDate             40
# BatchNo               3322
# MRP                      1
# LotNo                 3666
# SerialNo              1306
# dtype: int64

# %%
# get number of unique values for each column
counts = df.nunique()
# record columns to delete

# %%
counts
# Out:
# LocationCode             1
# CreatedOn              108
# No                     375
# ReleaseDatetime        102
# VendorCode               9
# VendorName               9
# PONO                   120
# PODate                  45
# PlannedReceiptDate      25
# ItemNo                 694
# ItemNo2                694
# Description            703
# Qty                      1
# UOM                      1
# Status                   2
# CreatedBy                3
# InvoiceNo              375
# InvoiceDate             40
# BatchNo               3322
# MRP                      1
# LotNo                 3666
# SerialNo              1306
# dtype: int64

# %%
to_del = [i for i,v in enumerate(counts) if v == 1]

print(to_del)
# drop useless columns
# Out:
# [0, 12, 13, 19]

# %%
to_del
# Out:
# [0, 12, 13, 19]

# %%
df
# Out:
#        LocationCode            CreatedOn             No      ReleaseDatetime  \
# 1     JAKSON_KAROLI  2022-05-08 00:23:20  AASN/2223/371  2022-05-08 00:23:34
# 2     JAKSON_KAROLI  2022-05-08 00:23:20  AASN/2223/371  2022-05-08 00:23:34
# 3     JAKSON_KAROLI  2022-05-08 00:23:20  AASN/2223/371  2022-05-08 00:23:34
# 4     JAKSON_KAROLI  2022-05-08 00:23:20  AASN/2223/371  2022-05-08 00:23:34
# 5     JAKSON_KAROLI  2022-05-08 00:23:20  AASN/2223/371  2022-05-08 00:23:34
# ...             ...                  ...            ...                  ...
# 4975  JAKSON_KAROLI  2022-04-10 15:58:53   AASN/2223/87  2022-04-10 15:58:53
# 4976  JAKSON_KAROLI  2022-04-10 15:58:53   AASN/2223/87  2022-04-10 15:58:53
# 4977  JAKSON_KAROLI  2022-04-10 15:58:53   AASN/2223/87  2022-04-10 15:58:53
# 4978  JAKSON_KAROLI  2022-04-10 15:58:53   AASN/2223/87  2022-04-10 15:58:53
# 4979  JAKSON_KAROLI  2022-04-10 15:58:53   AASN/2223/87  2022-04-10 15:58:53
#
# ...

# %%
counts = df.nunique()
# record columns to delete
to_del = [i for i,v in enumerate(counts) if v == 1]
print(to_del)
# drop useless columns
df.drop(to_del, axis=1)
print(df.shape)
# Out:
# [0, 12, 13, 19]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10856/1737163138.py in <module>
#       4 print(to_del)
#       5 # drop useless columns
# ----> 6 df.drop(to_del, axis=1)
#       7 print(df.shape)
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
# drop useless columns
df.drop("LocationCode", axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10856/620009529.py in <module>
#       1 # drop useless columns
# ----> 2 df.drop("LocationCode", axis=1)
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
df
# Out:
#                 CreatedOn             No      ReleaseDatetime VendorCode  \
# 1     2022-05-08 00:23:20  AASN/2223/371  2022-05-08 00:23:34    OPS1001
# 2     2022-05-08 00:23:20  AASN/2223/371  2022-05-08 00:23:34    OPS1001
# 3     2022-05-08 00:23:20  AASN/2223/371  2022-05-08 00:23:34    OPS1001
# 4     2022-05-08 00:23:20  AASN/2223/371  2022-05-08 00:23:34    OPS1001
# 5     2022-05-08 00:23:20  AASN/2223/371  2022-05-08 00:23:34    OPS1001
# ...                   ...            ...                  ...        ...
# 4975  2022-04-10 15:58:53   AASN/2223/87  2022-04-10 15:58:53      V0251
# 4976  2022-04-10 15:58:53   AASN/2223/87  2022-04-10 15:58:53      V0251
# 4977  2022-04-10 15:58:53   AASN/2223/87  2022-04-10 15:58:53      V0251
# 4978  2022-04-10 15:58:53   AASN/2223/87  2022-04-10 15:58:53      V0251
# 4979  2022-04-10 15:58:53   AASN/2223/87  2022-04-10 15:58:53      V0251
#
#                       VendorName                 PONO               PODate  \
# ...

# %%
df.nunique()
# Out:
# CreatedOn              108
# No                     375
# ReleaseDatetime        102
# VendorCode               9
# VendorName               9
# PONO                   120
# PODate                  45
# PlannedReceiptDate      25
# ItemNo                 694
# ItemNo2                694
# Description            703
# Qty                      1
# UOM                      1
# Status                   2
# CreatedBy                3
# InvoiceNo              375
# InvoiceDate             40
# BatchNo               3318
# MRP                      1
# LotNo                 3662
# SerialNo              1306
# dtype: int64

# %%
count = df.nunique()
# record columns to delete
to_del = [i for i,v in enumerate(count) if v == 1]
print(to_del)
# drop useless columns
#df.drop(to_del, axis=1)
print(df.shape)
# Out:
# [11, 12, 18]
# (4976, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4976 entries, 1 to 4979
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CreatedOn           4976 non-null   object
#  1   No                  4976 non-null   object
#  2   ReleaseDatetime     4976 non-null   object
#  3   VendorCode          4976 non-null   object
#  4   VendorName          4976 non-null   object
#  5   PONO                4976 non-null   object
#  6   PODate              4976 non-null   object
#  7   PlannedReceiptDate  4976 non-null   object
#  8   ItemNo              4976 non-null   object
#  9   ItemNo2             4976 non-null   object
#  10  Description         4976 non-null   object
#  11  Qty                 4976 non-null   int64
#  12  UOM                 4976 non-null   object
#  13  Status              4976 non-null   object
#  14  CreatedBy           4976 non-null   int64
# ...

# %%
df.drop(["Qty", "UOM", "MRP" ], axis = 1, inplace= True)

# %%
df
# Out:
#                 CreatedOn             No      ReleaseDatetime VendorCode  \
# 1     2022-05-08 00:23:20  AASN/2223/371  2022-05-08 00:23:34    OPS1001
# 2     2022-05-08 00:23:20  AASN/2223/371  2022-05-08 00:23:34    OPS1001
# 3     2022-05-08 00:23:20  AASN/2223/371  2022-05-08 00:23:34    OPS1001
# 4     2022-05-08 00:23:20  AASN/2223/371  2022-05-08 00:23:34    OPS1001
# 5     2022-05-08 00:23:20  AASN/2223/371  2022-05-08 00:23:34    OPS1001
# ...                   ...            ...                  ...        ...
# 4975  2022-04-10 15:58:53   AASN/2223/87  2022-04-10 15:58:53      V0251
# 4976  2022-04-10 15:58:53   AASN/2223/87  2022-04-10 15:58:53      V0251
# 4977  2022-04-10 15:58:53   AASN/2223/87  2022-04-10 15:58:53      V0251
# 4978  2022-04-10 15:58:53   AASN/2223/87  2022-04-10 15:58:53      V0251
# 4979  2022-04-10 15:58:53   AASN/2223/87  2022-04-10 15:58:53      V0251
#
#                       VendorName                 PONO               PODate  \
# ...

# %%
cotton = df.nunique()
# record columns to delete
to_del = [i for i,v in enumerate(cotton) if v == 1]
print(to_del)
# drop useless columns
#df.drop(to_del, axis=1)
print(df.shape)
# Out:
# []
# (4976, 18)

# %%
for i in range(df.shape[1]):
num = len(unique(df.iloc[: , :i]))
percentage = float(num) / df.shape[0] * 100
print('%d, %d, %.1f%%' % (i, num, percentage))
# Out:
#   File "C:\Users\JITENDRA\AppData\Local\Temp/ipykernel_25484/183260214.py", line 2
#     num = len(unique(df.iloc[: , :i]))
#     ^
# IndentationError: expected an indented block

# %%
#from numpy import loadtxt
from numpy import unique
# load the dataset
#data = loadtxt('oil-spill.csv', delimiter=',')
# summarize the number of unique values in each column
for i in range(df.shape[1]):
 num = len(unique(df.iloc[:, i]))
 percentage = float(num) / df.shape[0] * 100
#if percentage < 1:
 #print('%d, %d, %.1f%%' % (i, num, percentage))\
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19688/2581321283.py in <module>
#       5 # summarize the number of unique values in each column
#       6 for i in range(df.shape[1]):
# ----> 7  num = len(unique(df.iloc[:, i]))
#       8  percentage = float(num) / df.shape[0] * 100
#       9 #if percentage < 1:
#
# <__array_function__ internals> in unique(*args, **kwargs)
#
# c:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     260     ar = np.asanyarray(ar)
#     261     if axis is None:
# --> 262         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     263         return _unpack_tuple(ret)
#     264
#
# c:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
# ...

# %%
num = len(unique(df[:, i]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25484/741013040.py in <module>
# ----> 1 num = len(unique(df[:, i]))
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3359             casted_key = self._maybe_cast_indexer(key)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#    3363                 raise KeyError(key) from err
#
# ...

# %%
counts = df.nunique()
to_del = [i for i,v in enumerate(counts) if (float(v)/df.shape[0]*100) < 1]

# %%
to_del
# Out:
# [0, 4, 5, 7, 8, 12, 13, 14, 15, 17, 19]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4980 entries, 0 to 4979
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   LocationCode        4980 non-null   object
#  1   CreatedOn           4980 non-null   object
#  2   No                  4980 non-null   object
#  3   ReleaseDatetime     4980 non-null   object
#  4   VendorCode          4980 non-null   object
#  5   VendorName          4980 non-null   object
#  6   PONO                4980 non-null   object
#  7   PODate              4980 non-null   object
#  8   PlannedReceiptDate  4980 non-null   object
#  9   ItemNo              4980 non-null   object
#  10  ItemNo2             4980 non-null   object
#  11  Description         4980 non-null   object
#  12  Qty                 4980 non-null   int64
#  13  UOM                 4980 non-null   object
#  14  Status              4980 non-null   object
# ...

# %%
x = df.iloc[: ,:-1]
y = df.iloc[:, -1]


y
# Out:
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
#            ...
# 4975    10203220513
# 4976    10203220510
# 4977    10203220511
# 4978    10203220512
# 4979    10203220513
# Name: SerialNo, Length: 4980, dtype: object

# %%
transform = VarianceThreshold(threshold=t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25484/1775961171.py in <module>
# ----> 1 transform = VarianceThreshold(threshold=t)
#
# NameError: name 'VarianceThreshold' is not defined

# %%
from numpy import arange
import pandas as pd
from sklearn.feature_selection import VarianceThreshold
from matplotlib import pyplot
# split data into inputs and outputs
data = df.values
X = data[:, :-1]
y = data[:, -1]
print(X.shape, y.shape)
# define thresholds to check
thresholds = arange(0.0, 0.55, 0.05)
# apply transform with each threshold
results = list()
for t in thresholds:
# define the transform
 transform = VarianceThreshold(threshold=t)
# transform the input data
X_sel = transform.fit_transform(X)
# determine the number of input features
n_features = X_sel.shape[1]
print('>Threshold=%.2f, Features=%d' % (t, n_features))
# store the result
results.append(n_features)
# plot the threshold vs the number of selected features
pyplot.plot(thresholds, results)
pyplot.show()
# Out:
# (4980, 21) (4980,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25484/433959047.py in <module>
#      16  transform = VarianceThreshold(threshold=t)
#      17 # transform the input data
# ---> 18 X_sel = transform.fit_transform(X)
#      19 # determine the number of input features
#      20 n_features = X_sel.shape[1]
#
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_selection\_variance_threshold.py in fit(self, X, y)
#      66         self
# ...
